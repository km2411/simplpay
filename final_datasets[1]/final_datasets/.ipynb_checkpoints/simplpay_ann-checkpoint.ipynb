# %%
import pandas as pd

# %%
credit = pd.read_csv('credit_data.csv')
user = pd.read_csv('users_data.csv')
txn = pd.read_csv('transactions_data.csv')
stlmt = pd.read_csv('settlements_data.csv')
cycles = pd.read_csv('cycles.csv')
fail = pd.read_csv('failure_events_data.csv')

# %%
user.columns
user.head(5)
# Out:
#    user_id referrer    email  name  city_id
# 0        1        a  1@1.com  oh t      4.0
# 1        2        a  2@2.com  nk s      7.0
# 2        3      NaN  3@1.com  itna      NaN
# 3        4        a  4@3.com   osn      3.0
# 4        5        a  5@1.com  um s      7.0

# %%
#clean the user data, make referrer boolean, drop city NaN
user['referrer'].nunique()
user['referrer'].loc[~user['referrer'].isna()] = 1
user['referrer'].loc[user['referrer'].isna()] = 0
#user.dropna(subset=['city_id']);
# Out:
# /home/kartik/Desktop/MOOCS/SuperDS/Deep_Learning_A_Z/dLA2Z/local/lib/python2.7/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#check for grouping in user, city
user.describe()
user.head(5)
# Out:
#    user_id  referrer    email  name  city_id
# 0        1         1  1@1.com  oh t      4.0
# 1        2         1  2@2.com  nk s      7.0
# 2        3         0  3@1.com  itna      NaN
# 3        4         1  4@3.com   osn      3.0
# 4        5         1  5@1.com  um s      7.0

# %%
#check for multi cities, group the user
user.groupby(['user_id', 'city_id']).filter(lambda x: len(x) > 1)
# Out:
# Empty DataFrame
# Columns: [user_id, referrer, email, name, city_id]
# Index: []

# %%
credit.info()
credit.describe()
#credit is all clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18468 entries, 0 to 18467
# Data columns (total 3 columns):
# user_id                18468 non-null int64
# cycle_id               18468 non-null int64
# global_credit_limit    18468 non-null int64
# dtypes: int64(3)
# memory usage: 432.9 KB
#             user_id      cycle_id  global_credit_limit
# count  18468.000000  18468.000000         18468.000000
# mean    8067.809129     14.217295        126512.887156
# std     4362.935645      4.649221         65312.491560
# min        1.000000      2.000000         50000.000000
# 25%     4284.750000     10.000000         75000.000000
# 50%     8436.500000     15.000000        150000.000000
# 75%    11720.250000     18.000000        150000.000000
# max    16045.000000     22.000000       1000000.000000

# %% [markdown]
# ##### IMP: Plot credit limit as y with cycle on the x, per user to see the trend.
# This would be helpful in finding peculiar cases.

# %%
import matplotlib.pyplot as plt

# %%
c = credit.groupby(['user_id'],as_index=False)

# %%
c.head(5)
# Out:
#        user_id  cycle_id  global_credit_limit
# 0         2358        15                75000
# 1         2358        18               150000
# 2        10504        21               150000
# 3        10504        16                75000
# 4         9948        14                75000
# 5         9948        16               150000
# 6         7021        12               200000
# 7         3022         7               150000
# 8        15747        18                75000
# 9         3177        12               500000
# 10        3177         8               150000
# 11        3557         7               150000
# 12       11176        17                75000
# 13       12745        21               150000
# 14       12745        19                75000
# 15       12786        19                75000
# 16        6679        20               200000
# 17        6679         7               150000
# 18       12272        18                75000
# 19        4544         7               150000
# 20        2275         7               150000
# 21        4875        10               150000
# 22        5390        15                75000
# 23        6753        12               150000
# 24        6238        11               150000
# 25       10356        16                75000
# 26       10356        21               150000
# 27       11014        17                75000
# 28       11014        19               150000
# 29        9533        12               150000
# ...        ...       ...                  ...
# 18438    14013        20                75000
# 18439    14013        21               150000
# 18440     1705        15                75000
# 18441    12701        19                75000
# 18442     9687        15               200000
# 18443    10428        14                75000
# 18444      904         7               150000
# 18445      904        13               200000
# 18446     1168         7               150000
# 18447     5910        10               150000
# 18448     5691        10               150000
# 18449    13653        20                75000
# 18450     6586        11               150000
# 18451     1374         7               150000
# 18452     2118        16               150000
# 18453     2118        15                75000
# 18454    13069        14                75000
# 18455    13069        20               150000
# 18456    10301        20               150000
# 18457    10301        16                75000
# 18458    12306        18                75000
# 18459    12306        21               150000
# 18460     5499         9               150000
# 18461     3811         9               150000
# 18462     5937         7                50000
# 18463     5937        14               150000
# 18464    15604        22               100000
# 18465     3671        15                75000
# 18466     1324         7               150000
# 18467      426         7               150000
#
# [18468 rows x 3 columns]

# %%
c = credit.pivot(index='user_id', columns='cycle_id', values='global_credit_limit');
c.head(5)
# Out:
# cycle_id        2         3   4   6   7   8   9   10  11  12  13       14  \
# user_id
# 1              NaN       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  75000.0
# 2              NaN  500000.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN      NaN
# 4              NaN  500000.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN      NaN
# 5         500000.0       NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN      NaN
# 6              NaN  500000.0 NaN NaN NaN NaN NaN NaN NaN NaN NaN      NaN
#
# cycle_id        15  16  17  18  19  20  21  22
# user_id
# 1         150000.0 NaN NaN NaN NaN NaN NaN NaN
# 2              NaN NaN NaN NaN NaN NaN NaN NaN
# 4              NaN NaN NaN NaN NaN NaN NaN NaN
# 5              NaN NaN NaN NaN NaN NaN NaN NaN
# 6              NaN NaN NaN NaN NaN NaN NaN NaN

# %% [markdown]
# ##### The above observation shows that time series analysis cannot be done because of missing data

# %%
cycles.head(5) #cycles is all clean
# Out:
#    cycle_id                       start_date                         end_date
# 0         1  2015-11-01 00:00:00 +0000 +0000  2015-11-15 00:00:00 +0000 +0000
# 1         2  2015-11-16 00:00:00 +0000 +0000  2015-11-30 23:59:59 +0000 +0000
# 2         3  2015-12-01 00:00:00 +0000 +0000  2015-12-15 00:00:00 +0000 +0000
# 3         4  2015-12-16 00:00:00 +0000 +0000  2015-12-31 23:59:59 +0000 +0000
# 4         5  2016-01-01 00:00:00 +0000 +0000  2016-01-15 23:59:59 +0000 +0000

# %%
len(cycles)
# Out:
# 23

# %% [markdown]
# #### The settlement data is very important
# <ul><li>To understand the metric for good and bad behaviour, we need to look at the one time settlements and delayed settlements individually.
#     <li>Metrics can be (onetime_amount/total_spend) and (delayed_amount/total_spend)*(-days_delayed)
# </ul>

# %%
#First let's clean the settlement data; encode if neccessary
#encode the settlement_status
stlmt['settlement_status'] = stlmt.settlement_status.astype('category').cat.codes

# %%
#bill_pending = 0, bill_settled = 1, onetime = 2
#cycle id missing?
stlmt['cycle_id'].loc[stlmt['cycle_id'].isnull() == True]
# Out:
# 28043   NaN
# 28060   NaN
# Name: cycle_id, dtype: float64

# %%
#drop cycle_id NaN
stlmt.dropna(subset=['cycle_id']);
#remove days_delayed NaN
stlmt['days_delayed'].loc[stlmt['days_delayed'].isna()] = 0
#stlmt.head(5)
stlmt = stlmt.drop(columns=['id'])

# %%
stlmt.head(5)
# Out:
#    user_id  cycle_id  settlement_amount  settlement_status  days_delayed  \
# 0     1738      21.0             190500                  2      0.000000
# 1     6055      20.0             138900                  1     14.966468
# 2    10630      20.0              43100                  1     14.985449
# 3     5766      21.0              75300                  2      0.000000
# 4    12416      20.0              38000                  1     14.971875
#
#                           bill_created_at  \
# 0                                     NaN
# 1  2016-08-31 16:16:00.874006 +0000 +0000
# 2  2016-08-31 15:47:52.453709 +0000 +0000
# 3                                     NaN
# 4  2016-08-31 16:05:29.841341 +0000 +0000
#
#                                settled_at
# 0  2016-09-15 15:29:45.245929 +0000 +0000
# 1   2016-09-15 15:27:43.69227 +0000 +0000
# 2  2016-09-15 15:26:55.238252 +0000 +0000
# 3  2016-09-15 15:26:20.622842 +0000 +0000
# 4  2016-09-15 15:24:59.843029 +0000 +0000

# %%
#we need total_spend_amount ; amount_settled_early ; amount_settled_late
#let's group by to see how the total spend amount comes out
f = {'settlement_amount':['sum']}
stlmt_total_spend = stlmt.groupby(['user_id', 'cycle_id'],as_index=False).agg(f)

# %%
stlmt_total_spend.columns = stlmt_total_spend.columns.droplevel(1)

# %%
stlmt_total_spend.columns
# Out:
# Index([u'user_id', u'cycle_id', u'settlement_amount'], dtype='object')

# %%
stlmt_total_spend = stlmt_total_spend.rename(index=str,columns = {'settlement_amount':'total_spend'})

# %%
stlmt_total_spend[60:70] #to check if sum for total spend is correct, ex.(12,8)
# Out:
#     user_id  cycle_id  total_spend
# 60       11      20.0        46700
# 61       12       8.0       163200
# 62       12       9.0        91500
# 63       12      10.0       232400
# 64       12      11.0       215500
# 65       12      12.0        52300
# 66       12      13.0        94000
# 67       12      14.0        80700
# 68       12      15.0       123300
# 69       12      16.0       289100

# %%
#first split the data into 3 -> 0, 1, 2 status

# %% [markdown]
# #### Onetime Amount

# %%
stlmt_onetime = stlmt.loc[stlmt['settlement_status']==2]

# %%
stlmt_onetime.head(5)
# Out:
#     user_id  cycle_id  settlement_amount  settlement_status  days_delayed  \
# 0      1738      21.0             190500                  2           0.0
# 3      5766      21.0              75300                  2           0.0
# 11    13439      21.0              23300                  2           0.0
# 12     2875      21.0              31900                  2           0.0
# 14    14269      21.0              56900                  2           0.0
#
#    bill_created_at                              settled_at
# 0              NaN  2016-09-15 15:29:45.245929 +0000 +0000
# 3              NaN  2016-09-15 15:26:20.622842 +0000 +0000
# 11             NaN  2016-09-15 15:11:54.071178 +0000 +0000
# 12             NaN  2016-09-15 15:10:08.857486 +0000 +0000
# 14             NaN  2016-09-15 15:09:11.348649 +0000 +0000

# %%
#select columns
stlmt_onetime = stlmt_onetime[['user_id','cycle_id','settlement_amount']];

# %%
stlmt_onetime.head(5)
# Out:
#     user_id  cycle_id  settlement_amount
# 0      1738      21.0             190500
# 3      5766      21.0              75300
# 11    13439      21.0              23300
# 12     2875      21.0              31900
# 14    14269      21.0              56900

# %%
#aggregate
f = {'settlement_amount':[sum]}
stlmt_onetime_agg = stlmt_onetime.groupby(['user_id', 'cycle_id'],as_index=False).agg(f)

# %%
stlmt_onetime_agg.columns = stlmt_onetime_agg.columns.droplevel(1)

# %%
stlmt_onetime_agg = stlmt_onetime_agg.rename(index=str,columns = {'settlement_amount':'onetime_amt'})

# %% [markdown]
# ####  'Dealyed Amount'

# %%
stlmt_delayed = stlmt.loc[stlmt['settlement_status']==1]
stlmt_delayed.head(5)
# Out:
#    user_id  cycle_id  settlement_amount  settlement_status  days_delayed  \
# 1     6055      20.0             138900                  1     14.966468
# 2    10630      20.0              43100                  1     14.985449
# 4    12416      20.0              38000                  1     14.971875
# 5    13371      20.0              14400                  1     14.968118
# 6    13172      20.0              26400                  1     14.953311
#
#                           bill_created_at  \
# 1  2016-08-31 16:16:00.874006 +0000 +0000
# 2  2016-08-31 15:47:52.453709 +0000 +0000
# 4  2016-08-31 16:05:29.841341 +0000 +0000
# 5  2016-08-31 16:07:39.286497 +0000 +0000
# 6  2016-08-31 16:27:01.547579 +0000 +0000
#
#                                settled_at
# 1   2016-09-15 15:27:43.69227 +0000 +0000
# 2  2016-09-15 15:26:55.238252 +0000 +0000
# 4  2016-09-15 15:24:59.843029 +0000 +0000
# 5  2016-09-15 15:21:44.661884 +0000 +0000
# 6  2016-09-15 15:19:47.578431 +0000 +0000

# %%
#select columns
stlmt_delayed = stlmt_delayed[['user_id','cycle_id','settlement_amount','days_delayed']];

# %%
#aggregate
f = {'settlement_amount':[sum],'days_delayed':[sum]}
stlmt_delayed_agg = stlmt_delayed.groupby(['user_id', 'cycle_id'],as_index=False).agg(f)

# %%
stlmt_delayed_agg.columns = stlmt_delayed_agg.columns.droplevel(1)

# %%
stlmt_delayed_agg = stlmt_delayed_agg.rename(index=str,columns = {'settlement_amount':'delayed_amt'})

# %%
stlmt_delayed_agg.head(5)
# Out:
#    user_id  cycle_id  delayed_amt  days_delayed
# 0        1      14.0        67200      0.023479
# 1        1      15.0        32500      0.044287
# 2        1      18.0       108600      0.010955
# 3        2       5.0        13000     10.377654
# 4        2       7.0        36500      0.235332

# %% [markdown]
# #### 'Pending Amount'

# %%
stlmt_pending = stlmt.loc[stlmt['settlement_status']==0]
stlmt_pending.head(5)
# Out:
#       user_id  cycle_id  settlement_amount  settlement_status  days_delayed  \
# 2909     8848      20.0              59900                  0           0.0
# 2910    12718      20.0              21400                  0           0.0
# 2911    11267      20.0              54600                  0           0.0
# 2912    12005      20.0             147400                  0           0.0
# 2914    13781      20.0               8600                  0           0.0
#
#                              bill_created_at settled_at
# 2909  2016-08-31 16:49:42.545263 +0000 +0000        NaN
# 2910  2016-08-31 16:49:41.952401 +0000 +0000        NaN
# 2911  2016-08-31 16:49:29.127541 +0000 +0000        NaN
# 2912  2016-08-31 16:49:27.747393 +0000 +0000        NaN
# 2914  2016-08-31 16:49:27.409813 +0000 +0000        NaN

# %%
stlmt_pending = stlmt_pending[['user_id','cycle_id','settlement_amount']];

# %%
#aggregate
f = {'settlement_amount':[sum]}
stlmt_pending_agg = stlmt_pending.groupby(['user_id', 'cycle_id'],as_index=False).agg(f)

# %%
stlmt_pending_agg.columns = stlmt_pending_agg.columns.droplevel(1)

# %%
stlmt_pending_agg = stlmt_pending_agg.rename(index=str,columns = {'settlement_amount':'pending_amt'})

# %%
#add a column with boolean pending, later will fillna with 1 for others after join

# %%
stlmt_pending_agg['is_pending'] = 1

# %%
stlmt_pending_agg.head(5)
# Out:
#    user_id  cycle_id  pending_amt  is_pending
# 0        2      19.0        81100           1
# 1        7      15.0        11700           1
# 2       18       6.0        20000           1
# 3       21      17.0        57300           1
# 4       22      11.0        13000           1

# %% [markdown]
# #### For the user which has pending status, he will not have any future cycles (make pending as boolean, repayment future would be -inf with 0 credit limit)
# It will be interesting to see the trend of somebody who has had all the 3 natures. (not possible because of missing data maybe)

# %%
print len(stlmt), len(stlmt_total_spend), len(stlmt_onetime), len(stlmt_delayed), len(stlmt_pending)
print len(stlmt), len(stlmt_total_spend), len(stlmt_onetime_agg), len(stlmt_delayed_agg), len(stlmt_pending_agg)
# Out:
# 30683 28598 5703 22395 2585
# 30683 28598 5020 22395 2585

# %% [markdown]
# #### Now we must join all the types of spend per user, per cycle and fillna appropriately.
# Left Join would make sense?

# %%
#join first the total with delayed
stlmt_all = pd.merge(stlmt_total_spend,stlmt_delayed_agg, how='left', left_on=['user_id','cycle_id'], right_on = ['user_id','cycle_id'])

# %%
stlmt_all.head(5)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  days_delayed
# 0        1      14.0        67200      67200.0      0.023479
# 1        1      15.0        32500      32500.0      0.044287
# 2        1      18.0       108600     108600.0      0.010955
# 3        2       5.0        13000      13000.0     10.377654
# 4        2       7.0        36500      36500.0      0.235332

# %%
#join stlmt_all with onetime
stlmt_all = pd.merge(stlmt_all,stlmt_onetime_agg, how='left', left_on=['user_id','cycle_id'], right_on = ['user_id','cycle_id'])

# %%
stlmt_all.head(5)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  days_delayed  onetime_amt
# 0        1      14.0        67200      67200.0      0.023479          NaN
# 1        1      15.0        32500      32500.0      0.044287          NaN
# 2        1      18.0       108600     108600.0      0.010955          NaN
# 3        2       5.0        13000      13000.0     10.377654          NaN
# 4        2       7.0        36500      36500.0      0.235332          NaN

# %%
#join stlmt_all with pending
stlmt_all = pd.merge(stlmt_all,stlmt_pending_agg, how='left', left_on=['user_id','cycle_id'], right_on = ['user_id','cycle_id'])

# %%
stlmt_all.head(5)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  days_delayed  onetime_amt  \
# 0        1      14.0        67200      67200.0      0.023479          NaN
# 1        1      15.0        32500      32500.0      0.044287          NaN
# 2        1      18.0       108600     108600.0      0.010955          NaN
# 3        2       5.0        13000      13000.0     10.377654          NaN
# 4        2       7.0        36500      36500.0      0.235332          NaN
#
#    pending_amt  is_pending
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN

# %%
len(stlmt_all)
# Out:
# 28598

# %% [markdown]
# #### VVImp - Fillna with appropriate values

# %%
#now create metrics, is_pending might be dummy as pending_amt is already there

# %%
#fraction for delayed, onetime, pending
stlmt_all['delayed_amt'] = (stlmt_all['delayed_amt']/stlmt_all['total_spend'])*stlmt_all['days_delayed']

# %%
stlmt_all['onetime_amt'] = stlmt_all['onetime_amt']/stlmt_all['total_spend']
stlmt_all['pending_amt'] = stlmt_all['pending_amt']/stlmt_all['total_spend']

# %%
stlmt_all = stlmt_all.fillna(0)

# %%
#drop irrelevant columns
stlmt_all = stlmt_all.drop(columns=['days_delayed','is_pending'])

# %%
stlmt_all[10:20]
# Out:
#     user_id  cycle_id  total_spend  delayed_amt  onetime_amt  pending_amt
# 10        2      14.0        96600    13.601391          0.0          0.0
# 11        2      15.0        35000     0.646585          0.0          0.0
# 12        2      16.0       419949    13.564712          0.0          0.0
# 13        2      17.0        22000     2.571479          0.0          0.0
# 14        2      18.0        57630     0.982984          0.0          0.0
# 15        2      19.0        81100     0.000000          0.0          1.0
# 16        4       8.0        15000     0.000000          1.0          0.0
# 17        4      13.0        30000     3.586420          0.0          0.0
# 18        4      14.0        35000     0.774737          0.0          0.0
# 19        4      15.0        21000    10.970861          0.0          0.0

# %%
#when crossing stlmt_all with itself for the final vector, 
#ass there are many missing cycles, it would be interesting to cycle_id_x < cycle_id_y
#and from that keep only the closet pair ex. 13-21 13-16 13-18, keep 13-16

# %%
#join with transaction, credit and user data

# %% [markdown]
# ###### modify the tables with timestamp fields to respective cycle, based on time range

# %%
#write a function that takes the data frane as input, the column name and appends the cycle_id
def getCycleId(df, colname):
    #change the colname type tp datetime
    df[colname] = pd.to_datetime(df[colname])
    #create a new col, cycle_id
    df['cycle_id'] = 0
    
    #now check for each cycle range and assign cycle_id
    for index, row in cycles.iterrows():
        st = row['start_date']
        end = row['end_date']
        cid = row['cycle_id']
        df['cycle_id'].loc[(df[colname] >= st) & (df[colname]<= end)] = cid

# %%
getCycleId(txn,'created_at')
getCycleId(fail,'created_at')

# %%
#change amount to Rs.
fail['transaction_amount'] = fail['amount_in_paise']/100

# %% [markdown]
# ### Let's visualize and look for patterns

# %% [markdown]
# ##### There could be two main aspects to no repayment -
# 1. Customers nature/ habit (Inherent)
# 2. Dissatisfaction (Induced)<br>
# <b>Note:</b> Interesting would to be figure out when somebody forgets (nature not recurrent - False Positives)

# %%
fail_new = fail[['user_id','cycle_id', 'transaction_id', 'transaction_amount','failure_type']]
fail_new.head(5)
fail_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17993 entries, 0 to 17992
# Data columns (total 5 columns):
# user_id               17993 non-null int64
# cycle_id              17993 non-null int64
# transaction_id        17993 non-null int64
# transaction_amount    17993 non-null float64
# failure_type          17993 non-null object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 702.9+ KB

# %%
#aggregate
f = {'transaction_id':['count']}
fail_new  = fail_new.groupby(['user_id', 'cycle_id'],as_index=False).agg(f)

# %%
fail_new.head(5)
# Out:
#   user_id cycle_id transaction_id
#                             count
# 0       1       14              1
# 1       2        6              3
# 2       2       11              1
# 3       2       12              3
# 4       2       15              2

# %%
fail_new.columns = fail_new.columns.droplevel(1)

# %%
fail_new = fail_new.rename(index=str,columns = {'transaction_id':'num_failed_txns'})

# %%
fail_new.head(5)
# Out:
#    user_id  cycle_id  num_failed_txns
# 0        1        14                1
# 1        2         6                3
# 2        2        11                1
# 3        2        12                3
# 4        2        15                2

# %% [markdown]
# ##### Let's work with transactions data
# split first into latest and old(repayed transactions)

# %%
txn.head(5)
# Out:
#    transaction_id  user_id  merchant_id  transaction_amount  \
# 0          141695    13693            1               10100
# 1          141694     8166            1               20900
# 2          141688    15886            1               28100
# 3          141686    12014            8               18000
# 4          141684    12392            1               63500
#
#                   created_at  cycle_id
# 0 2016-09-30 15:29:10.228672        22
# 1 2016-09-30 15:29:00.286923        22
# 2 2016-09-30 15:27:55.801021        22
# 3 2016-09-30 15:27:17.891471        22
# 4 2016-09-30 15:25:56.857979        22

# %%
txn_22 = txn[txn['cycle_id']==22]

# %%
txn_22.size
# Out:
# 51996

# %%
txn.size
# Out:
# 442386

# %%
txn_old = txn[txn['cycle_id']!=22]
txn_old = txn_old.drop(columns=['created_at']);
txn_old.head(5)
# Out:
#       transaction_id  user_id  merchant_id  transaction_amount  cycle_id
# 8666          125783    14496            1               13200        21
# 8667          125782     4054            1               19300        21
# 8668          125779    14501            1               19200        21
# 8669          125776      189            1               19800        21
# 8670          125775     6212            1               20400        21

# %%
txn_old.size
txn_old.merchant_id.unique()
# Out:
# array([ 1, 18, 10, 13,  7, 11,  6,  8, 14,  9, 15,  2,  3, 17, 16, 12,  4,
#         5])

# %%
#tables of interest left -> user, txns, credit, settlements
user.columns
# Out:
# Index([u'user_id', u'referrer', u'email', u'name', u'city_id'], dtype='object')

# %%
user_rel = user.drop(columns=['email','name']);
user_rel.head(5)
# Out:
#    user_id  referrer  city_id
# 0        1         1      4.0
# 1        2         1      7.0
# 2        3         0      NaN
# 3        4         1      3.0
# 4        5         1      7.0

# %%
credit.head(5)
# Out:
#    user_id  cycle_id  global_credit_limit
# 0     2358        15                75000
# 1     2358        18               150000
# 2    10504        21               150000
# 3    10504        16                75000
# 4     9948        14                75000

# %%
user_rel.head(5) #we need to add user and credit data to the above dataframe, 
                 #then we will cross to get cycle = cycle+1
# Out:
#    user_id  referrer  city_id
# 0        1         1      4.0
# 1        2         1      7.0
# 2        3         0      NaN
# 3        4         1      3.0
# 4        5         1      7.0

# %%
credit.head(5)
# Out:
#    user_id  cycle_id  global_credit_limit
# 0     2358        15                75000
# 1     2358        18               150000
# 2    10504        21               150000
# 3    10504        16                75000
# 4     9948        14                75000

# %%
txn_old.head(10)
# Out:
#       transaction_id  user_id  merchant_id  transaction_amount  cycle_id
# 8666          125783    14496            1               13200        21
# 8667          125782     4054            1               19300        21
# 8668          125779    14501            1               19200        21
# 8669          125776      189            1               19800        21
# 8670          125775     6212            1               20400        21
# 8671          125774    14489           18               20079        21
# 8672          125771    13439            1               19000        21
# 8673          125769     3320            1               18200        21
# 8674          125768    12980            1               52800        21
# 8675          125767     3474            1               23900        21

# %%
#aggregate
f = {'transaction_id':['count']}
txn_old = txn_old.groupby(['user_id', 'cycle_id'],as_index=False).agg(f)

# %%
txn_old.columns = txn_old.columns.droplevel(1)
txn_old = txn_old.rename(index=str,columns = {'transaction_id':'num_sucsfl_txns'})

# %%
txn_old.head(5)
# Out:
#    user_id  cycle_id  num_sucsfl_txns
# 0        1        14                3
# 1        1        15                1
# 2        1        18                2
# 3        2         5                1
# 4        2         6                2

# %%
print len(stlmt_all), len(txn_old), len(credit), len(user_rel), len(fail_new)
# Out:
# 28598 32981 18468 16050 11093

# %%
#join stlmt_all with txns
stlmt_all_new = pd.merge(stlmt_all,txn_old, how='left', left_on=['user_id','cycle_id'], right_on = ['user_id','cycle_id'])

# %%
stlmt_all_new.head(10)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  onetime_amt  pending_amt  \
# 0        1      14.0        67200     0.023479          0.0          0.0
# 1        1      15.0        32500     0.044287          0.0          0.0
# 2        1      18.0       108600     0.010955          0.0          0.0
# 3        2       5.0        13000    10.377654          0.0          0.0
# 4        2       7.0        36500     0.235332          0.0          0.0
# 5        2       8.0        42200     0.779108          0.0          0.0
# 6        2       9.0        21200     0.742215          0.0          0.0
# 7        2      10.0        32900     5.651593          0.0          0.0
# 8        2      11.0        11700     6.647299          0.0          0.0
# 9        2      12.0        74300     8.467596          0.0          0.0
#
#    num_sucsfl_txns
# 0              3.0
# 1              1.0
# 2              2.0
# 3              1.0
# 4              3.0
# 5              2.0
# 6              1.0
# 7              1.0
# 8              1.0
# 9              3.0

# %%
x = stlmt_all_new.num_sucsfl_txns.isna()

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x = x[x!= False]
len(x) #these could indicate cycles with only failed txns are there, lets see
# Out:
# 195

# %%
len(fail_new)
# Out:
# 11093

# %%
#join stlmt_all with credit
stlmt_all_new = pd.merge(stlmt_all_new,credit, how='left', left_on=['user_id','cycle_id'], right_on = ['user_id','cycle_id'])

# %%
stlmt_all_new.head(10)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  onetime_amt  pending_amt  \
# 0        1      14.0        67200     0.023479          0.0          0.0
# 1        1      15.0        32500     0.044287          0.0          0.0
# 2        1      18.0       108600     0.010955          0.0          0.0
# 3        2       5.0        13000    10.377654          0.0          0.0
# 4        2       7.0        36500     0.235332          0.0          0.0
# 5        2       8.0        42200     0.779108          0.0          0.0
# 6        2       9.0        21200     0.742215          0.0          0.0
# 7        2      10.0        32900     5.651593          0.0          0.0
# 8        2      11.0        11700     6.647299          0.0          0.0
# 9        2      12.0        74300     8.467596          0.0          0.0
#
#    num_sucsfl_txns  global_credit_limit
# 0              3.0              75000.0
# 1              1.0             150000.0
# 2              2.0                  NaN
# 3              1.0                  NaN
# 4              3.0                  NaN
# 5              2.0                  NaN
# 6              1.0                  NaN
# 7              1.0                  NaN
# 8              1.0                  NaN
# 9              3.0                  NaN

# %% [markdown]
# ##### Strange that credit data is not available for so many users/cycles

# %%
#join stlmt_all with fail_new
stlmt_all_new = pd.merge(stlmt_all_new,fail_new, how='left', left_on=['user_id','cycle_id'], right_on = ['user_id','cycle_id'])

# %%
stlmt_all_new.head(10)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  onetime_amt  pending_amt  \
# 0        1      14.0        67200     0.023479          0.0          0.0
# 1        1      15.0        32500     0.044287          0.0          0.0
# 2        1      18.0       108600     0.010955          0.0          0.0
# 3        2       5.0        13000    10.377654          0.0          0.0
# 4        2       7.0        36500     0.235332          0.0          0.0
# 5        2       8.0        42200     0.779108          0.0          0.0
# 6        2       9.0        21200     0.742215          0.0          0.0
# 7        2      10.0        32900     5.651593          0.0          0.0
# 8        2      11.0        11700     6.647299          0.0          0.0
# 9        2      12.0        74300     8.467596          0.0          0.0
#
#    num_sucsfl_txns  global_credit_limit  num_failed_txns
# 0              3.0              75000.0              1.0
# 1              1.0             150000.0              NaN
# 2              2.0                  NaN              NaN
# 3              1.0                  NaN              NaN
# 4              3.0                  NaN              NaN
# 5              2.0                  NaN              NaN
# 6              1.0                  NaN              NaN
# 7              1.0                  NaN              NaN
# 8              1.0                  NaN              1.0
# 9              3.0                  NaN              3.0

# %%
#join stlmt_all with user_rel
stlmt_all_new = pd.merge(stlmt_all_new,user_rel, how='left', left_on=['user_id'], right_on = ['user_id'])

# %%
stlmt_all_new.head(10)
# Out:
#    user_id  cycle_id  total_spend  delayed_amt  onetime_amt  pending_amt  \
# 0        1      14.0        67200     0.023479          0.0          0.0
# 1        1      15.0        32500     0.044287          0.0          0.0
# 2        1      18.0       108600     0.010955          0.0          0.0
# 3        2       5.0        13000    10.377654          0.0          0.0
# 4        2       7.0        36500     0.235332          0.0          0.0
# 5        2       8.0        42200     0.779108          0.0          0.0
# 6        2       9.0        21200     0.742215          0.0          0.0
# 7        2      10.0        32900     5.651593          0.0          0.0
# 8        2      11.0        11700     6.647299          0.0          0.0
# 9        2      12.0        74300     8.467596          0.0          0.0
#
#    num_sucsfl_txns  global_credit_limit  num_failed_txns  referrer  city_id
# 0              3.0              75000.0              1.0         1      4.0
# 1              1.0             150000.0              NaN         1      4.0
# 2              2.0                  NaN              NaN         1      4.0
# 3              1.0                  NaN              NaN         1      7.0
# 4              3.0                  NaN              NaN         1      7.0
# 5              2.0                  NaN              NaN         1      7.0
# 6              1.0                  NaN              NaN         1      7.0
# 7              1.0                  NaN              NaN         1      7.0
# 8              1.0                  NaN              1.0         1      7.0
# 9              3.0                  NaN              3.0         1      7.0

# %%
len(stlmt_all_new)
# Out:
# 28598

# %% [markdown]
# #### Now we want to get the vector with user info, current cycle info and next cycle (this would be predition label)

# %%
df_next_cycle = stlmt_all_new[['user_id','cycle_id','global_credit_limit']]

# %%
df_next_cycle.head(5)
# Out:
#    user_id  cycle_id  global_credit_limit
# 0        1      14.0              75000.0
# 1        1      15.0             150000.0
# 2        1      18.0                  NaN
# 3        2       5.0                  NaN
# 4        2       7.0                  NaN

# %%
df_current = stlmt_all_new
df_next_cycle = df_next_cycle.rename(index=str, columns = {'user_id':'user_id_y','cycle_id':'cycle_id_y' })

# %%
df_final = pd.merge(df_current, df_next_cycle, how='outer', left_on=['user_id'], right_on=['user_id_y'])

# %%
df_final1 = df_final.loc[(df_final.user_id == df_final.user_id_y) & (df_final.cycle_id +1 == df_final.cycle_id_y)]

# %%
df_final1.head(10)
# Out:
#      user_id  cycle_id  total_spend  delayed_amt  onetime_amt  pending_amt  \
# 1          1      14.0        67200     0.023479          0.0          0.0
# 24         2       7.0        36500     0.235332          0.0          0.0
# 38         2       8.0        42200     0.779108          0.0          0.0
# 52         2       9.0        21200     0.742215          0.0          0.0
# 66         2      10.0        32900     5.651593          0.0          0.0
# 80         2      11.0        11700     6.647299          0.0          0.0
# 108        2      14.0        96600    13.601391          0.0          0.0
# 122        2      15.0        35000     0.646585          0.0          0.0
# 136        2      16.0       419949    13.564712          0.0          0.0
# 150        2      17.0        22000     2.571479          0.0          0.0
#
#      num_sucsfl_txns  global_credit_limit_x  num_failed_txns  referrer  \
# 1                3.0                75000.0              1.0         1
# 24               3.0                    NaN              NaN         1
# 38               2.0                    NaN              NaN         1
# 52               1.0                    NaN              NaN         1
# 66               1.0                    NaN              NaN         1
# 80               1.0                    NaN              1.0         1
# 108              3.0                    NaN              NaN         1
# 122              1.0                    NaN              2.0         1
# 136             14.0                    NaN              NaN         1
# 150              1.0                    NaN              2.0         1
#
#      city_id  user_id_y  cycle_id_y  global_credit_limit_y
# 1        4.0          1        15.0               150000.0
# 24       7.0          2         8.0                    NaN
# 38       7.0          2         9.0                    NaN
# 52       7.0          2        10.0                    NaN
# 66       7.0          2        11.0                    NaN
# 80       7.0          2        12.0                    NaN
# 108      7.0          2        15.0                    NaN
# 122      7.0          2        16.0                    NaN
# 136      7.0          2        17.0                    NaN
# 150      7.0          2        18.0                    NaN

# %%
len(df_final1)
df_final1.columns
# Out:
# Index([u'user_id', u'cycle_id', u'total_spend', u'delayed_amt', u'onetime_amt',
#        u'pending_amt', u'num_sucsfl_txns', u'global_credit_limit_x',
#        u'num_failed_txns', u'referrer', u'city_id', u'user_id_y',
#        u'cycle_id_y', u'global_credit_limit_y'],
#       dtype='object')

# %%
#df_final1 = df_final1['user_id','referrer','city_id','cycle_id','global_credit_limit_x','total_spend','delayed_amt','onetime_amt','pending_amt','num_sucsfl_txns','num_failed_txns','cycle_id_y','global_credit_limit_y']
df_final2 = df_final1.drop(columns=['user_id_y'])

# %%
cols = df_final2.columns.tolist()

# %%
cols
# Out:
# ['user_id',
#  'cycle_id',
#  'total_spend',
#  'delayed_amt',
#  'onetime_amt',
#  'pending_amt',
#  'num_sucsfl_txns',
#  'global_credit_limit_x',
#  'num_failed_txns',
#  'referrer',
#  'city_id',
#  'cycle_id_y',
#  'global_credit_limit_y']

# %%
cols = ['user_id',
 'referrer',
 'city_id',
 'cycle_id',
 'total_spend',
 'delayed_amt',
 'onetime_amt',
 'pending_amt',
 'num_sucsfl_txns',
 'global_credit_limit_x',
 'num_failed_txns',
 'cycle_id_y',
 'global_credit_limit_y']

# %%
df_final2 = df_final2[cols]

# %%
df_final2.head(10)
# Out:
#      user_id  referrer  city_id  cycle_id  total_spend  delayed_amt  \
# 1          1         1      4.0      14.0        67200     0.023479
# 24         2         1      7.0       7.0        36500     0.235332
# 38         2         1      7.0       8.0        42200     0.779108
# 52         2         1      7.0       9.0        21200     0.742215
# 66         2         1      7.0      10.0        32900     5.651593
# 80         2         1      7.0      11.0        11700     6.647299
# 108        2         1      7.0      14.0        96600    13.601391
# 122        2         1      7.0      15.0        35000     0.646585
# 136        2         1      7.0      16.0       419949    13.564712
# 150        2         1      7.0      17.0        22000     2.571479
#
#      onetime_amt  pending_amt  num_sucsfl_txns  global_credit_limit_x  \
# 1            0.0          0.0              3.0                75000.0
# 24           0.0          0.0              3.0                    NaN
# 38           0.0          0.0              2.0                    NaN
# 52           0.0          0.0              1.0                    NaN
# 66           0.0          0.0              1.0                    NaN
# 80           0.0          0.0              1.0                    NaN
# 108          0.0          0.0              3.0                    NaN
# 122          0.0          0.0              1.0                    NaN
# 136          0.0          0.0             14.0                    NaN
# 150          0.0          0.0              1.0                    NaN
#
#      num_failed_txns  cycle_id_y  global_credit_limit_y
# 1                1.0        15.0               150000.0
# 24               NaN         8.0                    NaN
# 38               NaN         9.0                    NaN
# 52               NaN        10.0                    NaN
# 66               NaN        11.0                    NaN
# 80               1.0        12.0                    NaN
# 108              NaN        15.0                    NaN
# 122              2.0        16.0                    NaN
# 136              NaN        17.0                    NaN
# 150              2.0        18.0                    NaN

# %%
df_final_new = df_final2.dropna(how='any')

# %%
print len(df_final2), len(df_final_new)
# Out:
# 11340 110

# %%
df_final_new.head(10)
# Out:
#        user_id  referrer  city_id  cycle_id  total_spend  delayed_amt  \
# 1            1         1      4.0      14.0        67200     0.023479
# 3147       257         1      2.0      15.0        63300     2.764614
# 6376       645         1      7.0      16.0       183000     0.304857
# 18595     1918         1      3.0      15.0        75100     2.480088
# 19450     1979         1      3.0      15.0       111400     0.315929
# 31854     3084         1     22.0       7.0        27100     0.001716
# 32358     3105         1      5.0       7.0        57000     1.481518
# 64682     4981         1      3.0      15.0        53500     0.650463
# 84058     6525         1      1.0      15.0        46800     3.060505
# 87034     6727         1      5.0      12.0       197200     0.419296
#
#        onetime_amt  pending_amt  num_sucsfl_txns  global_credit_limit_x  \
# 1         0.000000          0.0              3.0                75000.0
# 3147      0.000000          0.0              3.0                75000.0
# 6376      0.819672          0.0              6.0               150000.0
# 18595     0.343542          0.0              2.0                75000.0
# 19450     0.589767          0.0              5.0                75000.0
# 31854     0.000000          0.0              1.0                50000.0
# 32358     0.440351          0.0              3.0                50000.0
# 64682     0.000000          0.0              3.0                75000.0
# 84058     0.000000          0.0              2.0                75000.0
# 87034     0.580629          0.0              5.0               150000.0
#
#        num_failed_txns  cycle_id_y  global_credit_limit_y
# 1                  1.0        15.0               150000.0
# 3147               4.0        16.0               150000.0
# 6376               6.0        17.0               200000.0
# 18595              3.0        16.0               150000.0
# 19450              2.0        16.0               150000.0
# 31854              1.0         8.0               150000.0
# 32358              2.0         8.0               150000.0
# 64682              3.0        16.0               150000.0
# 84058              1.0        16.0               150000.0
# 87034              2.0        13.0               200000.0

# %%
df_final_new = df_final_new.drop(columns=['user_id','cycle_id','cycle_id_y'])

# %%
df_final_new.head(10)
# Out:
#        referrer  city_id  total_spend  delayed_amt  onetime_amt  pending_amt  \
# 1             1      4.0        67200     0.023479     0.000000          0.0
# 3147          1      2.0        63300     2.764614     0.000000          0.0
# 6376          1      7.0       183000     0.304857     0.819672          0.0
# 18595         1      3.0        75100     2.480088     0.343542          0.0
# 19450         1      3.0       111400     0.315929     0.589767          0.0
# 31854         1     22.0        27100     0.001716     0.000000          0.0
# 32358         1      5.0        57000     1.481518     0.440351          0.0
# 64682         1      3.0        53500     0.650463     0.000000          0.0
# 84058         1      1.0        46800     3.060505     0.000000          0.0
# 87034         1      5.0       197200     0.419296     0.580629          0.0
#
#        num_sucsfl_txns  global_credit_limit_x  num_failed_txns  \
# 1                  3.0                75000.0              1.0
# 3147               3.0                75000.0              4.0
# 6376               6.0               150000.0              6.0
# 18595              2.0                75000.0              3.0
# 19450              5.0                75000.0              2.0
# 31854              1.0                50000.0              1.0
# 32358              3.0                50000.0              2.0
# 64682              3.0                75000.0              3.0
# 84058              2.0                75000.0              1.0
# 87034              5.0               150000.0              2.0
#
#        global_credit_limit_y
# 1                   150000.0
# 3147                150000.0
# 6376                200000.0
# 18595               150000.0
# 19450               150000.0
# 31854               150000.0
# 32358               150000.0
# 64682               150000.0
# 84058               150000.0
# 87034               200000.0

# %% [markdown]
# ### Let's try building a model for prediction
